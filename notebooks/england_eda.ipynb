# %% [markdown]
# ### England, John | Final Project EDA
# ---

# %%
# Import Libraries
import sys 
import matplotlib 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from pandas import DataFrame, read_csv

# Enable inline plotting
# %matplotlib inline

# Version Control
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Numpy version ' + np.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.11.5 (main, Sep 11 2023, 08:19:27) [Clang 14.0.6 ]
# Pandas version 2.0.3
# Numpy version 1.24.3
# Matplotlib version 3.7.2

# %%
pwd
# Out:
# '/Users/stinkydog/Desktop/DSA_601/scripts'

# %%
service = pd.read_csv('/Users/stinkydog/Desktop/DSA_601/data/service.csv')
# https://data.buffalony.gov/Quality-of-Life/311-Service-Requests/whkc-e5vr/about_data

weather = pd.read_csv('/Users/stinkydog/Desktop/DSA_601/data/weather.csv')
# https://mesonet.agron.iastate.edu/vtec/search.php#byugc/NYC029
# Out:
# /var/folders/32/h_9nbrl13s73c2_31mnv0cdm0000gn/T/ipykernel_20750/1836491096.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   service = pd.read_csv('/Users/stinkydog/Desktop/DSA_601/data/service.csv')

# %%
weather.shape
# Out:
# (533, 14)

# %%
weather
# Out:
#                iso_issued            issued           iso_expired  \
# 0    2010-01-25T10:56:00Z  2010-01-25 10:56  2010-01-25T14:45:00Z
# 1    2010-01-25T13:56:00Z  2010-01-25 13:56  2010-01-25T18:27:00Z
# 2    2010-01-25T14:51:00Z  2010-01-25 14:51  2010-01-25T18:27:00Z
# 3    2010-01-25T15:00:00Z  2010-01-25 15:00  2010-01-25T21:48:00Z
# 4    2010-01-26T05:10:00Z  2010-01-26 05:10  2010-01-26T09:42:00Z
# ..                    ...               ...                   ...
# 528  2023-08-10T18:12:00Z  2023-08-10 18:12  2023-08-10T19:15:00Z
# 529  2023-08-12T16:36:00Z  2023-08-12 16:36  2023-08-12T16:43:00Z
# 530  2024-01-26T12:17:00Z  2024-01-26 12:17  2024-01-26T18:03:00Z
# 531  2024-01-27T21:50:00Z  2024-01-27 21:50  2024-01-28T01:30:00Z
# 532  2024-01-28T09:00:00Z  2024-01-28 09:00  2024-01-29T23:38:00Z
#
#               expired  eventid phenomena significance hvtec_nwsli  wfo  \
# 0    2010-01-25 14:45        2        FA            Y       00000  BUF
# ...
